# %%
thedict = {'african': 327,
 'african-american': 66,
 'albanian': 40,
 'american': 1,
 'ancient-celtic': 27,
 'ancient-egyptian': 18,
 'ancient-germanic': 262,
 'ancient-greek': 332,
 'ancient-irish': 28,
 'ancient-near-eastern': 12,
 'ancient-persian': 15,
 'ancient-roman': 222,
 'ancient-scandinavian': 174,
 'anglo-saxon': 86,
 'anglo-saxon-mythology': 6,
 'arabic': 729,
 'armenian': 79,
 'armenian-mythology': 1,
 'arthurian-romance': 18,
 'astronomy': 12,
 'azerbaijani': 24,
 'aztec-mythology': 3,
 'baltic-mythology': 1,
 'bashkir': 1,
 'basque': 163,
 'belarusian': 5,
 'bengali': 7,
 'biblical': 405,
 'biblical-greek': 97,
 'biblical-hebrew': 132,
 'biblical-latin': 84,
 'bosnian': 21,
 'breton': 28,
 'bulgarian': 157,
 'catalan': 74,
 'caucasian-mythology': 1,
 'celtic-mythology': 14,
 'chechen': 16,
 'chinese': 71,
 'cornish': 16,
 'corsican': 2,
 'croatian': 277,
 'czech': 225,
 'dagestani': 2,
 'danish': 126,
 'dutch': 356,
 'egyptian-mythology': 36,
 'english': 3405,
 'esperanto': 52,
 'estonian': 36,
 'far-eastern-mythology': 6,
 'finnish': 388,
 'finnish-mythology': 12,
 'french': 604,
 'frisian': 59,
 'galician': 18,
 'georgian': 124,
 'georgian-mythology': 2,
 'german': 589,
 'germanic-mythology': 10,
 'greek': 151,
 'greek-mythology': 295,
 'hawaiian': 48,
 'hebrew': 370,
 'hinduism': 4,
 'history': 90,
 'hungarian': 310,
 'icelandic': 63,
 'incan-mythology': 1,
 'indian': 520,
 'indigenous-australian': 1,
 'indonesian': 53,
 'iranian': 166,
 'irish': 567,
 'irish-mythology': 36,
 'italian': 734,
 'japanese': 266,
 'jewish': 5,
 'judeo-christian-legend': 14,
 'kazakh': 29,
 'khmer': 17,
 'korean': 31,
 'kurdish': 10,
 'kyrgyz': 7,
 'late-greek': 22,
 'late-roman': 163,
 'latvian': 66,
 'limburgish': 35,
 'literature': 75,
 'lithuanian': 132,
 'macedonian': 77,
 'manx': 10,
 'maori': 28,
 'mayan-mythology': 1,
 'medieval': 120,
 'mongolian': 19,
 'mormon': 1,
 'mythology': 4,
 'native-american': 62,
 'near-eastern-mythology': 37,
 'new-world-mythology': 1,
 'norse-mythology': 50,
 'norwegian': 126,
 'occitan': 8,
 'old-church-slavic': 30,
 'ossetian': 3,
 'ottoman-turkish': 2,
 'pacific-polynesian': 1,
 'pacific-polynesian-mythology': 5,
 'pakistani': 26,
 'pashto': 1,
 'persian-mythology': 33,
 'pet': 1,
 'polish': 355,
 'popular-culture': 9,
 'portuguese': 254,
 'punjabi': 18,
 'roman-mythology': 67,
 'romanian': 131,
 'russian': 415,
 'sami': 6,
 'scandinavian': 1,
 'scottish': 268,
 'serbian': 118,
 'slavic-mythology': 13,
 'slovak': 45,
 'slovene': 164,
 'spanish': 550,
 'swedish': 325,
 'tagalog': 1,
 'tajik': 2,
 'tamil': 1,
 'tatar': 6,
 'thai': 27,
 'theology': 10,
 'tibetan': 2,
 'turkish': 326,
 'turkmen': 5,
 'ukrainian': 59,
 'unknown': 26,
 'uyghur': 10,
 'uzbek': 9,
 'various': 64,
 'vietnamese': 47,
 'welsh': 321,
 'welsh-mythology': 25,
 'yiddish': 111}

# %%
import csv
with open('name_origins.csv', 'wb') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter='\t',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for key in thedict.keys():
        csvwriter.writerow([key, thedict[key]])
